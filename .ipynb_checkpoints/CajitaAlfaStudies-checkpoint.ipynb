# %% [markdown]
# Imports & Function definitions

# %%
from ROOT import TF2, TH1D, TF1, TFile, TCanvas, gROOT
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import ROOT
import pandas as pd
from matplotlib.ticker import NullFormatter, MaxNLocator
from numpy import linspace
from ipynb.fs.full.niceplots import hist2d_withprojections;
from scipy import stats
from mpl_toolkits.mplot3d import Axes3D 
import itertools


def April_Ntuple_to_df_List(month,ntuple,channels):
    mylist=[]
    aux=[]
    for run in ntuple:
        df1 = ROOT.RDataFrame("ntuple","AnalysisROOT%s/Run%i_NTuple.root" %(month,run))
        Qdf1 = ROOT.RDataFrame("charge","AnalysisROOT%s/Run%i_NTuple.root" %(month,run))
        diccionario=df1.AsNumpy()
        Qdiccionario=Qdf1.AsNumpy()
        aspd=pd.DataFrame(diccionario)
        Qaspd=pd.DataFrame(Qdiccionario)
        april_all_pd=pd.DataFrame.join(aspd,Qaspd)
        for ch in range(channels):
            aux.append(april_all_pd[april_all_pd["ch"]==ch])
        
        mylist.append(aux)
        
    return mylist;

def plot_var_wall(df1,colors,ch,var,wall_var,wall,axes=None,nbins=250,xlabel="",ylabel="Counts"):
    fig=plt.figure(figsize=(9,6), dpi= 100, facecolor='w', edgecolor='k')
    plt.hist(df1[(df1["ch"]==ch) ][var],nbins,axes,histtype ='bar', ec='black',color=colors[0]);
    plt.hist(df1[(df1["ch"]==ch) & (df1[wall_var]<wall)][var],nbins,axes,histtype ='bar', ec='black',color=colors[1]);
    plt.hist(df1[(df1["ch"]==ch) & (df1[wall_var]>wall)][var],nbins,axes,histtype ='bar', ec='black',color=colors[2]);
    plt.minorticks_on()
    plt.xlabel(xlabel, fontsize=16)  
    plt.ylabel(ylabel, fontsize=16)            

def multi_plot_same_run(df1,colors,ch,var,axes=None,nbins=100,leyenda=[],log=False):
    fig=plt.figure(figsize=(9,6), dpi= 100, facecolor='w', edgecolor='k')
    for i in range(len(var)):
        plt.hist(df1[(df1["ch"]==ch) ][var[i]],nbins,axes,histtype ='step',color=colors[i]);
    plt.xlabel("Charge (pC)", fontsize=16)  
    plt.ylabel("Counts", fontsize=16)            
    plt.minorticks_on()
    plt.legend(leyenda)
    if log==True:
        plt.yscale('log')

# %% [markdown]
# Load ROOT Files

# %%
#Open the ROOT TNtuples

apr_ntupla=[12,26,38,50,62];
may_ntupla=[15,27,39];
apr_cosmics_ntupla=[13,27,39,51];
apr_low_trigger=[5];
april_list=April_Ntuple_to_df_List("_April",apr_ntupla,3)
april_cosmics_list=April_Ntuple_to_df_List("_April",apr_cosmics_ntupla,3)

may_list=April_Ntuple_to_df_List("",may_ntupla,3)#may

# %% [markdown]
# Mayo separando por TDiff

# %%
#Mayo
plot_var_wall(may_list[0][0],["blue","tab:green","tab:orange"],0,"TEndQPeak","TEndQPeak",1.55e-6,[1e-6,2e-6])
plot_var_wall(may_list[0][0],["blue","tab:green","tab:orange"],0,"QPeak","TDiff",2.5e-7,[0,2500])
plot_var_wall(may_list[0][0],["blue","tab:green","tab:orange"],0,"QFixRange4","TDiff",2.5e-7,[0,3000])

# %% [markdown]
# Charge comparation plots

# %%
ch=0;
colors=["blue","green","red","yellow"]
var=["QPeak","QFixRange2", "QFixRange3", "QFixRange4"]
# legend=["Carga hasta recuperar Baseline","Carga","","",""]
nbins=200
multi_plot_same_run(may_list[0][0],colors,ch,["QPeak"],[500,2500],nbins,["Mayo: Carga hasta recuperar Baseline"],log=True)
multi_plot_same_run(april_list[0][0],colors,ch,["QPeak"],[100,500],nbins,["Abril: Carga hasta recuperar Baseline"],log=True)

# %%
ch=0;#PMT
colors=["blue","yellow","green","purple"]
var=["QFixRange1","QFixRange2", "QFixRange3", "QFixRange4"]
nbins=200

# legend=["1.4 $𝜇s$ (1300+100 ns)","3.3 $𝜇s$","4.3 $𝜇s$","5.3 $𝜇s$"]
# multi_plot_same_run(april_list[0],colors,ch,var,[0,500],nbins,legend)

# legend=["1.4 $𝜇s$ (1300+100 ns)","6.3 $𝜇s$","7.3 $𝜇s$","8.3 $𝜇s$"]
# multi_plot_same_run(may_list[0],colors,ch,var,[500,3500],nbins,legend)

var=["QFixRange4","QPeakRange4"]
legend=["Fix Range for all Event", "Range relative to Peak"]
multi_plot_same_run(may_list[0][0],colors,ch,var,[500,3500],nbins,legend)
multi_plot_same_run(april_list[0][0],colors,ch,var,[0,600],nbins,legend)

# %% [markdown]
# Abril buscar variable para separar chepas

# %%
#Abril
wall=1.46e-6
day=3
plot_var_wall(april_list[day][0],["blue","tab:green","tab:orange"],0,"TEndQPeak","TEndQPeak",wall,[1e-6,2e-6])
plot_var_wall(april_list[day][0],["blue","tab:green","tab:orange"],0,"QPeak","TEndQPeak",wall,[0,500])
plot_var_wall(april_list[day][0],["blue","tab:green","tab:orange"],0,"QFixRange4","TEndQPeak",wall,[0,500])

# %%
plot_var_wall(april_list[0][0],["blue","tab:green","tab:orange"],0,"TDiff","TDiff",0.9e-7,[0,0.9e-6])

# %% [markdown]
# F100 Plots

# %%
# df1=may_list[0][0]
df1=april_list[0][0]

f100=df1["QPeakRange1"]/df1["QPeakRange4"];

fig=plt.figure(figsize=(9,6), dpi= 80, facecolor='w', edgecolor='k')
# h=plt.hist2d(df1["QPeakRange4"],f100,200,[[8e3,15e3],[0,1]],norm=LogNorm());
# plt.xlabel("Carga Total (pC)", fontsize=16)
# plt.ylabel("F$_{100}$: $Q_{100ns}/Q_{Total}$", fontsize=16)  

h=plt.hist2d(df1["Amp"],f100,200,[[2e3,10e3],[0,1]],norm=LogNorm());
plt.xlabel("Amp (ADC counts)", fontsize=16)
plt.ylabel("F$_{100}$: $Q_{100ns}/Q_{Total}$", fontsize=16)  

plt.colorbar(h[3])
plt.show()


fig=plt.figure(figsize=(9,6), dpi= 80, facecolor='w', edgecolor='k')

h=plt.hist2d(df1["TDiff"],f100,100,[[0,0.4e-6],[0,1]],norm=LogNorm());
plt.xlabel("TDiff (ADC counts)", fontsize=16)
plt.ylabel("F$_{100}$: $Q_{100ns}/Q_{Total}$", fontsize=16)  

plt.colorbar(h[3])
plt.show()

fig=plt.figure(figsize=(9,6), dpi= 80, facecolor='w', edgecolor='k')

h=plt.hist2d(df1["TEndQPeak"],f100,100,[[1.2e-6,1.8e-6],[0,1]],norm=LogNorm());
plt.xlabel("TDiff (ADC counts)", fontsize=16)
plt.ylabel("F$_{100}$: $Q_{100ns}/Q_{Total}$", fontsize=16)  

plt.colorbar(h[3])
plt.show()


# hist2d_withprojections(df1["Amp"]/1000,df1["QFixRange1"], "Amp (ADC x$10^3$)","Q$_{100 ns}$")

# %%
plot_var_wall(april_list[0][0],["blue","tab:green","tab:orange"],0,"QPeak","TStartQpeak",1.305e-6,[0,500])

# %%
# plt.hist2(april_list[0][2]["QPeakRange4"],150,[[200,500],[0,1.5]]);
axes=[0,2e-6];
sampling=4e-9;
nbins=round((axes[1]-axes[0])/sampling)

fig=plt.figure(figsize=(12,6), dpi= 100, facecolor='w', edgecolor='k')
plt.hist(may_list[0][0]["TStartQpeak"],nbins,axes);
plt.hist(may_list[0][0]["TEndQPeak"],nbins,axes);
plt.hist(may_list[0][0]["TDiff"],nbins,axes);
plt.legend(["TStart","TEnd","TDiff"])

plt.xlabel("Time (s)", fontsize=16)
plt.ylabel("Counts", fontsize=16)
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# Correlations

# %%
PMT=april_list[0][0][["Amp","TStartQpeak","TEndQPeak","TDiff","QFixRange4"]]
SiPM1=april_list[0][1][["Amp","TStartQpeak","TEndQPeak","TDiff","QFixRange4"]]
SiPM2=april_list[0][2][["Amp","TStartQpeak","TEndQPeak","TDiff","QFixRange4"]]


# PMT=may_list[0][0][["Amp","TStartQpeak","TEndQPeak","TDiff","QFixRange4"]]
# SiPM1=may_list[0][1][["Amp","TStartQpeak","TEndQPeak","TDiff","QFixRange4"]]
# SiPM2=may_list[0][2][["Amp","TStartQpeak","TEndQPeak","TDiff","QFixRange4"]]

PMT.columns=["Amp$_{PMT}$","TStartQpeak$_{PMT}$","TEndQPeak$_{PMT}$","TDiff$_{PMT}$","QTotal$_{PMT}$"]
SiPM1.columns=["Amp$_{SiPM1}$","TStartQpeak$_{SiPM1}$","TEndQPeak$_{SiPM1}$","TDiff$_{SiPM1}$","QTotal$_{SiPM1}$"]
SiPM2.columns=["Amp$_{SiPM2}$","TStartQpeak$_{SiPM2}$","TEndQPeak$_{SiPM2}$","TDiff$_{SiPM2}$","QTotal$_{SiPM2}$"]

PMT=PMT.reset_index(drop=True)
SiPM1=SiPM1.reset_index(drop=True)
SiPM2=SiPM2.reset_index(drop=True)

aux=pd.DataFrame.join(PMT,SiPM1)
total=pd.DataFrame.join(aux,SiPM2)
total["F100$_{PMT}$"]=(april_list[0][0][["QPeakRange1"]].values/PMT[["QTotal$_{PMT}$"]].values)
total["F100$_{SiPM1}$"]=(april_list[0][1][["QPeakRange1"]].values/SiPM1[["QTotal$_{SiPM1}$"]].values)
total["F100$_{SiPM2}$"]=(april_list[0][2][["QPeakRange1"]].values/SiPM2[["QTotal$_{SiPM2}$"]].values)
# total["F100$_{PMT}$"]=(may_list[0][0][["QPeakRange1"]].values/PMT[["QTotal$_{PMT}$"]].values)
# total["F100$_{SiPM1}$"]=(may_list[0][1][["QPeakRange1"]].values/SiPM1[["QTotal$_{SiPM1}$"]].values)
# total["F100$_{SiPM2}$"]=(may_list[0][2][["QPeakRange1"]].values/SiPM2[["QTotal$_{SiPM2}$"]].values)

total["Qtotal$_{BothSiPM}$"]=(SiPM1[["QTotal$_{SiPM1}$"]].values+SiPM2[["QTotal$_{SiPM2}$"]].values)

total_light=total[["QTotal$_{PMT}$","Amp$_{PMT}$","TEndQPeak$_{PMT}$","TEndQPeak$_{SiPM1}$","TEndQPeak$_{SiPM2}$","Qtotal$_{BothSiPM}$"]]

total_light
# Out:
#       QTotal$_{PMT}$  Amp$_{PMT}$  TEndQPeak$_{PMT}$  TEndQPeak$_{SiPM1}$  \
# 0         359.516602  5770.419922           0.000001             0.000002
# 1         296.915039  5117.523926           0.000001             0.000002
# 2         408.723633  5970.251953           0.000001             0.000002
# 3         275.051758  4796.771973           0.000001             0.000002
# 4         289.798828  4520.576172           0.000001             0.000002
# ...              ...          ...                ...                  ...
# 8575      309.588867  4865.755859           0.000001             0.000002
# 8576      377.015625  5502.056152           0.000001             0.000002
# 8577      349.641602  5658.211914           0.000001             0.000002
# 8578      268.257812  4579.744141           0.000001             0.000002
# 8579      398.726562  5785.704102           0.000001             0.000002
#
#       TEndQPeak$_{SiPM2}$  Qtotal$_{BothSiPM}$
# 0                0.000002           392.251953
# 1                0.000002           380.545898
# 2                0.000002           471.012695
# 3                0.000002           412.552734
# 4                0.000002           380.634766
# ...                   ...                  ...
# 8575             0.000002           428.072266
# 8576             0.000002           394.009766
# 8577             0.000002           346.161133
# 8578             0.000002           421.433594
# 8579             0.000002           462.646484
#
# [8580 rows x 6 columns]

# %%
total.corr(method='pearson').style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-11-d966d22c3bd1>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   total.corr(method='pearson').style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_71e1f_row0_col0, #T_71e1f_row1_col1, #T_71e1f_row2_col2, #T_71e1f_row2_col3, #T_71e1f_row3_col2, #T_71e1f_row3_col3, #T_71e1f_row4_col4, #T_71e1f_row5_col5, #T_71e1f_row6_col6, #T_71e1f_row7_col7, #T_71e1f_row7_col8, #T_71e1f_row8_col7, #T_71e1f_row8_col8, #T_71e1f_row9_col9, #T_71e1f_row10_col10, #T_71e1f_row11_col11, #T_71e1f_row12_col12, #T_71e1f_row12_col13, #T_71e1f_row13_col12, #T_71e1f_row13_col13, #T_71e1f_row14_col14, #T_71e1f_row15_col15, #T_71e1f_row16_col16, #T_71e1f_row17_col17, #T_71e1f_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_71e1f_row0_col1, #T_71e1f_row2_col6, #T_71e1f_row7_col11, #T_71e1f_row10_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_71e1f_row0_col2, #T_71e1f_row10_col13 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_71e1f_row0_col3 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_71e1f_row0_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_71e1f_row0_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_71e1f_row0_col6, #T_71e1f_row14_col11 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_71e1f_row0_col7, #T_71e1f_row10_col8, #T_71e1f_row11_col3 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_71e1f_row0_col8, #T_71e1f_row2_col5, #T_71e1f_row11_col15 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_71e1f_row0_col9 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_71e1f_row0_col10, #T_71e1f_row5_col15, #T_71e1f_row6_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_71e1f_row0_col11, #T_71e1f_row4_col6, #T_71e1f_row4_col17, #T_71e1f_row7_col6, #T_71e1f_row8_col11, #T_71e1f_row8_col17, #T_71e1f_row9_col17, #T_71e1f_row17_col7, #T_71e1f_row17_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_71e1f_row0_col12, #T_71e1f_row0_col13, #T_71e1f_row3_col5, #T_71e1f_row6_col15, #T_71e1f_row10_col0, #T_71e1f_row18_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_71e1f_row0_col14 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_71e1f_row0_col15, #T_71e1f_row1_col17, #T_71e1f_row6_col10, #T_71e1f_row11_col16 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_71e1f_row0_col16, #T_71e1f_row0_col17, #T_71e1f_row1_col9, #T_71e1f_row11_col13, #T_71e1f_row12_col5, #T_71e1f_row13_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_71e1f_row0_col18, #T_71e1f_row2_col0, #T_71e1f_row3_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_71e1f_row1_col0, #T_71e1f_row1_col14, #T_71e1f_row2_col10, #T_71e1f_row3_col10 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_71e1f_row1_col2, #T_71e1f_row4_col5, #T_71e1f_row6_col3, #T_71e1f_row10_col7 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_71e1f_row1_col3 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_71e1f_row1_col4, #T_71e1f_row11_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_71e1f_row1_col5, #T_71e1f_row6_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_71e1f_row1_col6, #T_71e1f_row1_col11, #T_71e1f_row2_col14, #T_71e1f_row3_col14, #T_71e1f_row4_col9, #T_71e1f_row6_col1, #T_71e1f_row11_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_71e1f_row1_col7, #T_71e1f_row6_col13, #T_71e1f_row11_col12 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_71e1f_row1_col8, #T_71e1f_row6_col8, #T_71e1f_row6_col9 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_71e1f_row1_col10, #T_71e1f_row14_col6, #T_71e1f_row14_col15, #T_71e1f_row14_col16 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_71e1f_row1_col12 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_71e1f_row1_col13 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_71e1f_row1_col15, #T_71e1f_row5_col14 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_71e1f_row1_col16, #T_71e1f_row6_col16, #T_71e1f_row6_col17 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_71e1f_row1_col18, #T_71e1f_row11_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_71e1f_row2_col1, #T_71e1f_row4_col11, #T_71e1f_row7_col1, #T_71e1f_row9_col1, #T_71e1f_row18_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_71e1f_row2_col4, #T_71e1f_row3_col4 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_71e1f_row2_col7, #T_71e1f_row2_col9, #T_71e1f_row3_col7, #T_71e1f_row11_col6 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_71e1f_row2_col8, #T_71e1f_row3_col8, #T_71e1f_row3_col9, #T_71e1f_row12_col2, #T_71e1f_row12_col3, #T_71e1f_row13_col2, #T_71e1f_row13_col3 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_71e1f_row2_col11, #T_71e1f_row9_col11, #T_71e1f_row18_col6, #T_71e1f_row18_col11 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_71e1f_row2_col12, #T_71e1f_row2_col13, #T_71e1f_row3_col12, #T_71e1f_row3_col13 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_71e1f_row2_col15 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_71e1f_row2_col16, #T_71e1f_row13_col11, #T_71e1f_row14_col17 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_71e1f_row2_col17 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_71e1f_row2_col18, #T_71e1f_row3_col18, #T_71e1f_row12_col14, #T_71e1f_row13_col14 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_71e1f_row3_col1, #T_71e1f_row15_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_71e1f_row3_col6, #T_71e1f_row14_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_71e1f_row3_col11, #T_71e1f_row16_col14 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_71e1f_row3_col15 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_71e1f_row3_col16, #T_71e1f_row8_col6, #T_71e1f_row15_col1, #T_71e1f_row17_col18 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_71e1f_row3_col17, #T_71e1f_row8_col1, #T_71e1f_row9_col16, #T_71e1f_row12_col1, #T_71e1f_row17_col9 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_71e1f_row4_col0 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_71e1f_row4_col1, #T_71e1f_row16_col18 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_71e1f_row4_col2, #T_71e1f_row4_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_71e1f_row4_col7, #T_71e1f_row4_col8, #T_71e1f_row16_col15 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_71e1f_row4_col10 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_71e1f_row4_col12, #T_71e1f_row4_col13 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_71e1f_row4_col14 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_71e1f_row4_col15, #T_71e1f_row7_col16, #T_71e1f_row8_col16, #T_71e1f_row12_col17, #T_71e1f_row13_col17, #T_71e1f_row15_col0, #T_71e1f_row15_col2, #T_71e1f_row15_col3, #T_71e1f_row15_col4, #T_71e1f_row15_col5, #T_71e1f_row15_col9, #T_71e1f_row15_col10, #T_71e1f_row15_col14, #T_71e1f_row15_col18, #T_71e1f_row16_col6, #T_71e1f_row16_col7, #T_71e1f_row16_col8, #T_71e1f_row16_col11, #T_71e1f_row17_col1, #T_71e1f_row17_col6, #T_71e1f_row17_col12, #T_71e1f_row17_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_71e1f_row4_col16, #T_71e1f_row7_col17, #T_71e1f_row9_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_71e1f_row4_col18 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_71e1f_row5_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_71e1f_row5_col1, #T_71e1f_row5_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_71e1f_row5_col2, #T_71e1f_row5_col3, #T_71e1f_row10_col4 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_71e1f_row5_col4 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_71e1f_row5_col7, #T_71e1f_row5_col8 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_71e1f_row5_col9 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_71e1f_row5_col10, #T_71e1f_row7_col10, #T_71e1f_row9_col10 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_71e1f_row5_col11, #T_71e1f_row10_col6, #T_71e1f_row12_col15, #T_71e1f_row13_col15, #T_71e1f_row13_col16 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_71e1f_row5_col12, #T_71e1f_row11_col4 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_71e1f_row5_col13, #T_71e1f_ro

# %%
total.cov().style.background_gradient(cmap='coolwarm').set_precision(0)
# Out:
# <ipython-input-15-95189c70fd7d>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   total.cov().style.background_gradient(cmap='coolwarm').set_precision(0)
# <style type="text/css">
# #T_ccd86_row0_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_ccd86_row0_col1, #T_ccd86_row1_col15, #T_ccd86_row2_col15, #T_ccd86_row3_col15, #T_ccd86_row4_col0, #T_ccd86_row4_col2, #T_ccd86_row4_col3, #T_ccd86_row4_col4, #T_ccd86_row4_col5, #T_ccd86_row4_col7, #T_ccd86_row4_col8, #T_ccd86_row4_col9, #T_ccd86_row4_col10, #T_ccd86_row4_col12, #T_ccd86_row4_col13, #T_ccd86_row4_col14, #T_ccd86_row4_col18, #T_ccd86_row5_col16, #T_ccd86_row6_col15, #T_ccd86_row7_col15, #T_ccd86_row8_col15, #T_ccd86_row10_col6, #T_ccd86_row10_col11, #T_ccd86_row10_col17, #T_ccd86_row11_col15, #T_ccd86_row12_col15, #T_ccd86_row13_col15, #T_ccd86_row15_col15, #T_ccd86_row16_col15, #T_ccd86_row17_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ccd86_row0_col2, #T_ccd86_row0_col3, #T_ccd86_row0_col7, #T_ccd86_row0_col8, #T_ccd86_row0_col12, #T_ccd86_row0_col13, #T_ccd86_row5_col18 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_ccd86_row0_col4, #T_ccd86_row9_col4, #T_ccd86_row9_col12, #T_ccd86_row9_col13 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_ccd86_row0_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_ccd86_row0_col6 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_ccd86_row0_col9, #T_ccd86_row9_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_ccd86_row0_col10 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_ccd86_row0_col11 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_ccd86_row0_col14, #T_ccd86_row5_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_ccd86_row0_col15, #T_ccd86_row9_col17 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_ccd86_row0_col16, #T_ccd86_row9_col15, #T_ccd86_row14_col16 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_ccd86_row0_col17 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_ccd86_row0_col18 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_ccd86_row1_col0, #T_ccd86_row1_col2, #T_ccd86_row1_col3, #T_ccd86_row1_col4, #T_ccd86_row1_col5, #T_ccd86_row1_col7, #T_ccd86_row1_col8, #T_ccd86_row1_col9, #T_ccd86_row1_col10, #T_ccd86_row1_col12, #T_ccd86_row1_col13, #T_ccd86_row1_col14, #T_ccd86_row1_col18, #T_ccd86_row2_col0, #T_ccd86_row2_col2, #T_ccd86_row2_col3, #T_ccd86_row2_col4, #T_ccd86_row2_col5, #T_ccd86_row2_col7, #T_ccd86_row2_col8, #T_ccd86_row2_col9, #T_ccd86_row2_col10, #T_ccd86_row2_col12, #T_ccd86_row2_col13, #T_ccd86_row2_col14, #T_ccd86_row2_col18, #T_ccd86_row3_col0, #T_ccd86_row3_col2, #T_ccd86_row3_col3, #T_ccd86_row3_col4, #T_ccd86_row3_col5, #T_ccd86_row3_col7, #T_ccd86_row3_col8, #T_ccd86_row3_col9, #T_ccd86_row3_col10, #T_ccd86_row3_col12, #T_ccd86_row3_col13, #T_ccd86_row3_col14, #T_ccd86_row3_col18, #T_ccd86_row4_col1, #T_ccd86_row4_col6, #T_ccd86_row4_col11, #T_ccd86_row4_col15, #T_ccd86_row4_col16, #T_ccd86_row4_col17, #T_ccd86_row6_col0, #T_ccd86_row6_col2, #T_ccd86_row6_col3, #T_ccd86_row6_col4, #T_ccd86_row6_col5, #T_ccd86_row6_col7, #T_ccd86_row6_col8, #T_ccd86_row6_col9, #T_ccd86_row6_col10, #T_ccd86_row6_col12, #T_ccd86_row6_col13, #T_ccd86_row6_col14, #T_ccd86_row6_col18, #T_ccd86_row7_col0, #T_ccd86_row7_col2, #T_ccd86_row7_col3, #T_ccd86_row7_col4, #T_ccd86_row7_col5, #T_ccd86_row7_col7, #T_ccd86_row7_col8, #T_ccd86_row7_col9, #T_ccd86_row7_col10, #T_ccd86_row7_col12, #T_ccd86_row7_col13, #T_ccd86_row7_col14, #T_ccd86_row7_col18, #T_ccd86_row8_col0, #T_ccd86_row8_col2, #T_ccd86_row8_col3, #T_ccd86_row8_col4, #T_ccd86_row8_col5, #T_ccd86_row8_col7, #T_ccd86_row8_col8, #T_ccd86_row8_col9, #T_ccd86_row8_col10, #T_ccd86_row8_col12, #T_ccd86_row8_col13, #T_ccd86_row8_col14, #T_ccd86_row8_col18, #T_ccd86_row11_col0, #T_ccd86_row11_col2, #T_ccd86_row11_col3, #T_ccd86_row11_col4, #T_ccd86_row11_col5, #T_ccd86_row11_col7, #T_ccd86_row11_col8, #T_ccd86_row11_col9, #T_ccd86_row11_col10, #T_ccd86_row11_col12, #T_ccd86_row11_col13, #T_ccd86_row11_col14, #T_ccd86_row11_col18, #T_ccd86_row12_col0, #T_ccd86_row12_col2, #T_ccd86_row12_col3, #T_ccd86_row12_col4, #T_ccd86_row12_col5, #T_ccd86_row12_col7, #T_ccd86_row12_col8, #T_ccd86_row12_col9, #T_ccd86_row12_col10, #T_ccd86_row12_col12, #T_ccd86_row12_col13, #T_ccd86_row12_col14, #T_ccd86_row12_col18, #T_ccd86_row13_col0, #T_ccd86_row13_col2, #T_ccd86_row13_col3, #T_ccd86_row13_col4, #T_ccd86_row13_col5, #T_ccd86_row13_col7, #T_ccd86_row13_col8, #T_ccd86_row13_col9, #T_ccd86_row13_col10, #T_ccd86_row13_col12, #T_ccd86_row13_col13, #T_ccd86_row13_col14, #T_ccd86_row13_col18, #T_ccd86_row15_col0, #T_ccd86_row15_col2, #T_ccd86_row15_col3, #T_ccd86_row15_col4, #T_ccd86_row15_col5, #T_ccd86_row15_col7, #T_ccd86_row15_col8, #T_ccd86_row15_col9, #T_ccd86_row15_col10, #T_ccd86_row15_col12, #T_ccd86_row15_col13, #T_ccd86_row15_col14, #T_ccd86_row15_col18, #T_ccd86_row16_col0, #T_ccd86_row16_col2, #T_ccd86_row16_col3, #T_ccd86_row16_col4, #T_ccd86_row16_col5, #T_ccd86_row16_col7, #T_ccd86_row16_col8, #T_ccd86_row16_col9, #T_ccd86_row16_col10, #T_ccd86_row16_col12, #T_ccd86_row16_col13, #T_ccd86_row16_col14, #T_ccd86_row16_col18, #T_ccd86_row17_col0, #T_ccd86_row17_col2, #T_ccd86_row17_col3, #T_ccd86_row17_col4, #T_ccd86_row17_col5, #T_ccd86_row17_col7, #T_ccd86_row17_col8, #T_ccd86_row17_col9, #T_ccd86_row17_col10, #T_ccd86_row17_col12, #T_ccd86_row17_col13, #T_ccd86_row17_col14, #T_ccd86_row17_col18 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ccd86_row1_col1, #T_ccd86_row2_col1, #T_ccd86_row3_col1, #T_ccd86_row6_col1, #T_ccd86_row7_col1, #T_ccd86_row8_col1, #T_ccd86_row10_col10, #T_ccd86_row11_col1, #T_ccd86_row12_col1, #T_ccd86_row13_col1, #T_ccd86_row15_col1, #T_ccd86_row16_col1, #T_ccd86_row17_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_ccd86_row1_col6, #T_ccd86_row2_col6, #T_ccd86_row3_col6, #T_ccd86_row6_col6, #T_ccd86_row7_col6, #T_ccd86_row8_col6, #T_ccd86_row10_col1, #T_ccd86_row11_col6, #T_ccd86_row12_col6, #T_ccd86_row13_col6, #T_ccd86_row14_col11, #T_ccd86_row15_col6, #T_ccd86_row16_col6, #T_ccd86_row17_col6 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_ccd86_row1_col11, #T_ccd86_row2_col11, #T_ccd86_row3_col11, #T_ccd86_row6_col11, #T_ccd86_row7_col11, #T_ccd86_row8_col11, #T_ccd86_row11_col11, #T_ccd86_row12_col11, #T_ccd86_row13_col11, #T_ccd86_row14_col6, #T_ccd86_row15_col11, #T_ccd86_row16_col11, #T_ccd86_row17_col11 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_ccd86_row1_col16, #T_ccd86_row2_col16, #T_ccd86_row3_col16, #T_ccd86_row6_col16, #T_ccd86_row7_col16, #T_ccd86_row8_col16, #T_ccd86_row11_col16, #T_ccd86_row12_col16, #T_ccd86_row13_col16, #T_ccd86_row15_col16, #T_ccd86_row16_col16, #T_ccd86_row17_col16 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_ccd86_row1_col17, #T_ccd86_row2_col17, #T_ccd86_row3_col17, #T_ccd86_row6_col17, #T_ccd86_row7_col17, #T_ccd86_row8_col17, #T_ccd86_row11_col17, #T_ccd86_row12_col17, #T_ccd86_row13_col17, #T_ccd86_row15_col17, #T_ccd86_row16_col17, #T_ccd86_row17_col17 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_ccd86_row5_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_ccd86_row5_col2, #T_ccd86_row5_col3, #T_ccd86_row5_col4, #T_ccd86_row10_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_ccd86_row5_col5 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_ccd86_row5_col6 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_ccd86_row5_col7, #T_ccd86_row5_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_ccd86_row5_col9, #T_ccd86_row18_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_ccd86_row5_col10 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_ccd86_row5_col11 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_ccd86_row5_col12, #T_ccd86_row5_col13 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_ccd86_row5_col14 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_ccd86_row5_col15 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_ccd86_row5_col17 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_ccd86_row9_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_ccd86_row9_col2

# %%
total_light
# Out:
#       QTotal$_{PMT}$   Amp$_{PMT}$  TEndQPeak$_{PMT}$  TEndQPeak$_{SiPM1}$  \
# 0        2272.183594  11521.263672           0.000002             0.000002
# 1        2438.298828  11778.272461           0.000002             0.000002
# 2        2340.372070  11828.923828           0.000001             0.000002
# 3        2224.694336  11888.307617           0.000001             0.000002
# 4        2028.201172  11867.711914           0.000002             0.000002
# ...              ...           ...                ...                  ...
# 9995     2520.517578  11648.519531           0.000001             0.000002
# 9996     2432.487305  11999.507812           0.000001             0.000002
# 9997     2399.969727  11710.835938           0.000001             0.000002
# 9998     2446.958008  11926.019531           0.000002             0.000002
# 9999     2435.027344  11753.192383           0.000002             0.000002
#
#       TEndQPeak$_{SiPM2}$  Qtotal$_{BothSiPM}$
# 0                0.000002           558.187500
# 1                0.000002           575.874023
# 2                0.000002           548.270508
# 3                0.000002           644.484375
# 4                0.000002           467.004883
# ...                   ...                  ...
# 9995             0.000002           699.881836
# 9996             0.000002           508.158203
# 9997             0.000002           596.763672
# 9998             0.000002           502.195312
# 9999             0.000002           508.931641
#
# [10000 rows x 6 columns]

# %% [markdown]
# 3D PLots

# %%
total2=total[(total["QTotal$_{PMT}$"]<4000) & (total["Amp$_{PMT}$"]>9000)  & (total["Amp$_{PMT}$"]<14000) ]# & (total["TEndQPeak$_{PMT}$"]<1.6e-6)
total2=total2.reset_index(drop=True)

plt.ion()
myvars=["QTotal$_{PMT}$",
        "TEndQPeak$_{PMT}$",
        "Amp$_{PMT}$",
        "F100$_{PMT}$",
        "TEndQPeak$_{SiPM1}$",
        "TEndQPeak$_{SiPM2}$",
        "Qtotal$_{BothSiPM}$"]

counter=0;
combinations = list(itertools.combinations(myvars, 3))
combinations = list(combinations)
for myvars2 in combinations:            
    counter+=1;
    if (counter>1) & (counter>1):
        continue
    x = total2[myvars2[0]]
    y = total2[myvars2[1]]
    z = total2[myvars2[2]]

    xyz = np.vstack([x,y,z])
    density = stats.gaussian_kde(xyz)(xyz) 

    idx = density.argsort()
    x, y, z, density = x[idx], y[idx], z[idx], density[idx]

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(x, y, z, c=density,marker=".")
    ax.set_xlabel(myvars2[0], fontsize=14)
    ax.set_ylabel(myvars2[1], fontsize=14)
    ax.set_zlabel(myvars2[2], fontsize=14)

    plt.show()
plt.ioff()

# %% [markdown]
# Cosmics: 650ADC coincidencias SiPM 1 y 2

# %%
axes=[1e-6,5e-6]
nbins=100
# nbins=round((axes[1]-axes[0])/sampling)
# plt.hist(april_cosmics_list[0][1]["TEndQPeak"],nbins,axes);
# plt.hist(april_cosmics_list[0][2]["TEndQPeak"],nbins,axes);

all_cosmics_0=pd.concat([april_cosmics_list[0][0],april_cosmics_list[1][0],april_cosmics_list[2][0],april_cosmics_list[3][0]])
all_cosmics_1=pd.concat([april_cosmics_list[0][1],april_cosmics_list[1][1],april_cosmics_list[2][1],april_cosmics_list[3][1]])
all_cosmics_2=pd.concat([april_cosmics_list[0][2],april_cosmics_list[1][2],april_cosmics_list[2][2],april_cosmics_list[3][2]])

# fig=plt.figure(figsize=(6,4), dpi= 100, facecolor='w', edgecolor='k')
# plt.hist(all_cosmics_0["TEndQPeak"],nbins,axes);

fig=plt.figure(figsize=(16,8), dpi= 100, facecolor='w', edgecolor='k')
plt.hist(all_cosmics_0["QPeakRange4"],nbins,[0,10e3]);
plt.hist(april_list[0][0]["QPeakRange4"],nbins,[0,10e3]);
plt.yscale('log')

# plt.hist(all_cosmics_0["QPeakRange1"],nbins,[0,4e3]);

fig=plt.figure(figsize=(6,4), dpi= 100, facecolor='w', edgecolor='k')
plt.hist(all_cosmics_0["Amp"],nbins);

# %%
#Abril cosmics
plot_var_wall(all_cosmics_0,["blue","tab:green","tab:orange"],0,"TEndQPeak","TEndQPeak",3e-6,[1e-6,6e-6],100,"TEnd (s)")
plot_var_wall(all_cosmics_0,["blue","tab:green","tab:orange"],0,"QPeak","TEndQPeak",3e-6,[0,1e4],100,"Charge From peak to Baseline (pC)")
plot_var_wall(all_cosmics_0,["blue","tab:green","tab:orange"],0,"QFixRange4","TEndQPeak",3e-6,[0,1e4],100,"Total Charge (pC)")

# %%
april_cosmics_list[0][0].reset_index(drop=True)
time=(april_cosmics_list[0][0].iloc[-1]["time"]-april_cosmics_list[0][0].iloc[0]["time"])
# time/(2**10)
time*0.000000008/60
# all_cosmics_0.reset_index(drop=True)

df1=all_cosmics_0
f100=df1["QPeakRange1"]/df1["QPeakRange4"];

fig=plt.figure(figsize=(9,6), dpi= 80, facecolor='w', edgecolor='k')
# h=plt.hist2d(df1["QPeakRange4"],f100,200,[[8e3,15e3],[0,1]],norm=LogNorm());
# plt.xlabel("Carga Total (pC)", fontsize=16)
# plt.ylabel("F$_{100}$: $Q_{100ns}/Q_{Total}$", fontsize=16)  

h=plt.hist2d(df1["Amp"],f100,200,[[2e3,10e3],[0,1]],norm=LogNorm());
plt.xlabel("Amp (ADC counts)", fontsize=16)
plt.ylabel("F$_{100}$: $Q_{100ns}/Q_{Total}$", fontsize=16)  



df1=april_list[0][0]
f100=df1["QPeakRange1"]/df1["QPeakRange4"];
h=plt.hist2d(df1["Amp"],f100,200,[[2e3,10e3],[0,1]],norm=LogNorm());

plt.colorbar(h[3])


plt.show()

# %%
df1=april_list[0][0]
f100=df1["QPeakRange1"]/df1["QPeakRange4"];
h=plt.hist2d(df1["Amp"],f100,200,[[2e3,10e3],[0,1]],norm=LogNorm());

plt.colorbar(h[3])


plt.show()
print(len(f100[f100<0.6]))
print(len(f100[f100>0.6]))
print(len(f100[f100<0.6])/len(f100[f100>0.6]))
# Out:
# 49
# 8531
# 0.005743758058844215
